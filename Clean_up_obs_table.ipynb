# %% [markdown]
# ## Jan 2023
# ## Clean up OBS table

# %%
# !pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /opt/conda/lib/python3.9/site-packages (2022.12.0)
# Requirement already satisfied: cramjam>=2.3 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: pandas>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (1.5.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.9/site-packages (from fastparquet) (2022.8.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from fastparquet) (21.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (1.23.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2022.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->fastparquet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)

# %%
import pandas as pd
import numpy as np
import os as os

pd.set_option('display.max_rows', 500)

import seaborn as sns
import matplotlib as plt

datadir = '/challenge/seeing-through-the-fog/data/train_data'

# %%
df_obs = pd.read_parquet(datadir + "/" + "observations.parquet")

# %% [markdown]
# ## df_obs

# %%
df_obs.head()
# Out:
#        patientid obs_type obs_result obs_unit  days_to_covid_diag
# 0  RAADC3-364095      DBP         56    mm Hg                  12
# 1  RAADC3-364095      BMI       21.8     None                  12
# 2  RAADC3-364095    PULSE         72      bpm                  28
# 3  RAADC3-364095      SBP         95    mm Hg                  12
# 4  RAADC3-364095      DBP         58    mm Hg                  28

# %% [markdown]
# ### After dedup, only 1/3 of records remained

# %%
df_obs_dedup = df_obs.drop_duplicates()

# %%
print(df_obs.shape)
print(df_obs_dedup.shape)
# Out:
# (14734829, 5)
# (5662458, 5)

# %%
df_obs_dedup['obs_type'].unique()
# Out:
# array(['DBP', 'BMI', 'PULSE', 'SBP', 'TEMP', 'RESP', 'WT', 'HT', 'SMOKE',
#        'EXERCISE', 'ALCOHOL', 'HR', 'UROUT', 'PAIN',
#        'ACO.PHQ-2.DEPRESSION SCREEN', 'ACO.BP FOLLOW-UP',
#        'ADVANCED CARE DIRECTIVE: YES/NO', 'ACO.TOBACCO USE', 'LVEF',
#        'SMOKE_CESS_CONSULT', 'PACK_YEARS',
#        'SELF MONITORED BLOOD GLUCOSE (SMBG)',
#        '6-CLICKS INPT DLY ASSESS:QN1(HELP PT CURRENT NEEDS TO PUT ON/TAKE OFF LOWER BODY CLOTHING?)',
#        '6-CLICKS INPT DAILY ACTIVITY ASSESS:QN3(HELP PATIENT CURRENT NEEDS TOILETING?)',
#        '6-CLICKS INPT DLY ASSESS:QN4(HELP PT CURRENT NEEDS TO PUT ON/TAKE OFF UPPER BODY CLOTHING?)',
#        'ACO.PHQ-9.DEPRESSION SCREEN',
#        '6-CLICKS INPATIENT BASIC MOBILITY ASSESSMENT: TOTAL SCORE',
#        '6-CLICKS INPATIENT DAILY ACTIVITY ASSESSMENT: TOTAL SCORE',
#        '6-CLICKS INPT BASIC MOBIL ASSESS: QN3(DIFFICULTY PT HAS MOVING LYING ON BACK TO SIT ON BEDSIDE?)',
#        '6-CLICKS INPT DAILY ACTIVITY ASSESS:QN2(HELP PATIENT CURRENT NEEDS BATHING?)',
#        '6-CLICKS INPT BASIC MOBILITY ASSESS: QN5(HELP PT CURRENT NEEDS TO WALK IN HOSPITAL ROOM?)',
#        '6-CLICKS INPT BASIC MOBIL ASSESS: QN2(DIFFICULTY PT CURRENT HAS TO SIT DOWN/STAND UP FROM CHAIR?)',
#        '6-CLICKS INPT BASIC MOBIL ASSESS: QN6(HELP PT CURRENT NEEDS TO CLIMB 3-5 STEPS WITH A RAILING?)',
#        '6-CLICKS INPT DAILY ACTIVITY ASSESS:QN6(HELP PT CURRENT NEEDS EATING MEALS?)',
#        '6-CLICKS INPT BASIC MOBILITY ASSESS: QN4(HELP PT NEEDS MOVING TO AND FROM BED TO CHAIR?)',
#        '6-CLICKS INPT BASIC MOBIL ASSESS: QN1(DIFFICULTY PT CURRENT HAS TURNING OVER IN BED?)',
#        '6-CLICKS INPT DLY ACTIVE ASSESS:QN5(HELP PT CURRENT NEEDS TAKE CARE OF PERSONAL GROOMING?)',
#        'LAST MENSTRUAL PERIOD (LMP)', 'FVC', 'FEV1', 'FEV1_FVC_RATIO',
#        'ACO.BMI FOLLOW-UP', 'ACO.MORSE FALL SCALE (MFS)',
#        'ACO.TOBACCO CESSATION', 'ACO EXCLUSION.PREV.FLU VACCINE',
#        'ACO EXCLUSION.PREV.FALL RISK', 'ACO.OTHER FALL RISK SCORE',
#        'RISK SCORE (GENERIC)', 'T-SCORE.LOCATION UNSPECIFIED',
#        'PAIN SCORE; PROVIDER ASSESSED', 'PULMONARY FUNCTION TESTS',
#        'DIABETIC EYE EXAM (OBSERVATION)',
#        'ACO EXCLUSION.PREV.PNEUMO VACCINE',
#        'BREASTFEEDING STATUS (OBSERVATION)', 'ACO.DEPRESSION FOLLOW-UP',
#        'ACO.CAD LIPID CONTROL PLAN OF CARE', 'ACO EXCLUSION.PREV.BMI',
#        'HOSPICE INDICATOR', 'ACO.HENDRICH II FALL RISK MODEL',
#        'GESTATIONAL AGE; NONSPECIFIC', 'DYSPNEA_SCALE',
#        'T-SCORE.LUMBAR SPINE', 'PULSE.ORTHOSTATIC',
#        'DIASTOLIC BLOOD PRESSURE.ORTHOSTATIC',
#        'SYSTOLIC BLOOD PRESSURE.ORTHOSTATIC',
#        'ACO EXCLUSION.PREV.BLOOD PRESSURE', 'T-SCORE.FEMORAL NECK',
#        'T-SCORE.HIP', 'T-SCORE.FEMUR',
#        'POST-PRANDIAL BLOOD GLUCOSE (PPBG)',
#        'ACO 2015 EXCLUSION.DOCUMENTATION OF CURRENT MEDICATIONS',
#        'WEIGHT (LB)', 'FIM: TRANSFERS - TOILET SCORE',
#        'FIM: SPHINCTER CONTROL - BLADDER SCORE',
#        'FIM: SELF-CARE - TOILETING SCORE',
#        'FIM: SELF-CARE - DRESSING LOWER SCORE',
#        'FIM: COMMUNICATION - EXPRESSION SCORE (COMBINED OR UNKNOWN MODIFIER)',
#        'FIM: TRANSFERS - BED; CHAIR; WHEELCHAIR SCORE',
#        'FIM: SELF-CARE - EATING SCORE',
#        'FIM: SPHINCTER CONTROL - BOWEL SCORE',
#        'FIM: SELF-CARE - DRESSING UPPER SCORE',
#        'FIM: SOCIAL COGNITION - PROBLEM SOLVING SCORE',
#        'FIM: LOCOMOTION - WALK/WHEELCHAIR SCORE (WALK MODIFIER)',
#        'FIM: SELF-CARE - BATHING SCORE',
#        'FIM: COMMUNICATION - COMPREHENSION SCORE (COMBINED OR UNKNOWN MODIFIER)',
#        'FIM: TRANSFERS - TUB; SHOWER SCORE',
#        'FIM: SOCIAL COGNITION - MEMORY SCORE',
#        'FIM: SOCIAL COGNITION - SOCIAL INTERACTION SCORE',
#        'FIM: SELF-CARE - GROOMING SCORE',
#        'FIM: LOCOMOTION - STAIRS SCORE',
#        'ACO.GERIATRIC DEPRESSION SCALE (GDS)',
#        'ACO EXCLUSION.PREV.DEPRESSION', 'FVC_PCT_PRED', 'FEV1_PCT_PRED',
#        'ACO EXCLUSION.PREV.COLONOSCOPY',
#        'FIM: COMMUNICATION - COMPREHENSION SCORE (AUDITORY MODIFIER)',
#        'FIM: COMMUNICATION - COMPREHENSION SCORE (VISUAL MODIFIER)',
#        'FIM: COMMUNICATION - EXPRESSION SCORE (VOCAL MODIFIER)',
#        'FIM: LOCOMOTION - WALK/WHEELCHAIR SCORE (WHEELCHAIR MODIFIER)',
#        'FIM: COMMUNICATION - EXPRESSION SCORE (NON-VOCAL MODIFIER)',
#        'T-SCORE.WRIST', None, 'MPHQ DEPRESSION SCREEN FOR TEENS',
#        'T-SCORE.RADIUS', 'ACT ASSESSMENT SCORE',
#        'ACO EXCLUSION.PREV.MAMMOGRAPHY', 'T-SCORE.FOREARM'], dtype=object)

# %%
df_obs_top_obstype_count =  df_obs_dedup.groupby('obs_type')[['patientid']].count().\
reset_index().sort_values(by='patientid', ascending=False)

# %%
df_obs_top_obstype_count.shape
# Out:
# (106, 2)

# %%
df_obs_top_obstype_count
# Out:
#                                               obs_type  patientid
# 89                                                 SBP     908449
# 40                                                 DBP     815406
# 85                                               PULSE     750610
# 102                                               TEMP     425857
# 87                                                RESP     411511
# 38                                                 BMI     346390
# 105                                                 WT     345327
# 91                                               SMOKE     324166
# 76                                                  HT     265536
# 75                                                  HR     243456
# 37                                             ALCOHOL     219053
# 81                                                PAIN     183940
# 34                                     ACO.TOBACCO USE     124593
# 103                                              UROUT     114996
# 80                                          PACK_YEARS      54878
# 44                                            EXERCISE      19234
# 31                         ACO.PHQ-2.DEPRESSION SCREEN      14526
# 78                                                LVEF      10788
# 36                     ADVANCED CARE DIRECTIVE: YES/NO      10067
# 77                         LAST MENSTRUAL PERIOD (LMP)       8989
# 92                                  SMOKE_CESS_CONSULT       7493
# 33                               ACO.TOBACCO CESSATION       4501
# 82                       PAIN SCORE; PROVIDER ASSESSED       4457
# 32                         ACO.PHQ-9.DEPRESSION SCREEN       3942
# 90                 SELF MONITORED BLOOD GLUCOSE (SMBG)       3477
# 23                                   ACO.BMI FOLLOW-UP       3204
# 29                          ACO.MORSE FALL SCALE (MFS)       2578
# 0    6-CLICKS INPATIENT BASIC MOBILITY ASSESSMENT: ...       2307
# 30                           ACO.OTHER FALL RISK SCORE       2235
# 88                                RISK SCORE (GENERIC)       2141
# 1    6-CLICKS INPATIENT DAILY ACTIVITY ASSESSMENT: ...       1578
# 24                                    ACO.BP FOLLOW-UP       1317
# 9    6-CLICKS INPT DAILY ACTIVITY ASSESS:QN3(HELP P...       1266
# 13   6-CLICKS INPT DLY ASSESS:QN4(HELP PT CURRENT N...       1254
# 4    6-CLICKS INPT BASIC MOBIL ASSESS: QN3(DIFFICUL...       1244
# 12   6-CLICKS INPT DLY ASSESS:QN1(HELP PT CURRENT N...       1237
# 3    6-CLICKS INPT BASIC MOBIL ASSESS: QN2(DIFFICUL...       1226
# 11   6-CLICKS INPT DLY ACTIVE ASSESS:QN5(HELP PT CU...       1221
# 10   6-CLICKS INPT DAILY ACTIVITY ASSESS:QN6(HELP P...       1220
# 2    6-CLICKS INPT BASIC MOBIL ASSESS: QN1(DIFFICUL...       1218
# 8    6-CLICKS INPT DAILY ACTIVITY ASSESS:QN2(HELP P...       1215
# 6    6-CLICKS INPT BASIC MOBILITY ASSESS: QN4(HELP ...       1199
# 7    6-CLICKS INPT BASIC MOBILITY ASSESS: QN5(HELP ...       1183
# 5    6-CLICKS INPT BASIC MOBIL ASSESS: QN6(HELP PT ...       1168
# 19                        ACO EXCLUSION.PREV.FALL RISK       1072
# 98                        T-SCORE.LOCATION UNSPECIFIED        996
# 71                                                 FVC        904
# 45                                                FEV1        875
# 46                                      FEV1_FVC_RATIO        794
# 26                            ACO.DEPRESSION FOLLOW-UP        651
# 74                                   HOSPICE INDICATOR        632
# 28                     ACO.HENDRICH II FALL RISK MODEL        615
# 20                      ACO EXCLUSION.PREV.FLU VACCINE        318
# 16                              ACO EXCLUSION.PREV.BMI        209
# 73                        GESTATIONAL AGE; NONSPECIFIC        195
# 99                                T-SCORE.LUMBAR SPINE        163
# 15                   ACO EXCLUSION.PREV.BLOOD PRESSURE        150
# 94                                T-SCORE.FEMORAL NECK        148
# 93                 SYSTOLIC BLOOD PRESSURE.ORTHOSTATIC        146
# 42                DIASTOLIC BLOOD PRESSURE.ORTHOSTATIC        140
# 25                  ACO.CAD LIPID CONTROL PLAN OF CARE        139
# 41                     DIABETIC EYE EXAM (OBSERVATION)        135
# 39                  BREASTFEEDING STATUS (OBSERVATION)        135
# 66              FIM: SPHINCTER CONTROL - BLADDER SCORE        118
# 68       FIM: TRANSFERS - BED; CHAIR; WHEELCHAIR SCORE        116
# 62                    FIM: SELF-CARE - TOILETING SCORE        106
# 58               FIM: SELF-CARE - DRESSING LOWER SCORE        104
# 70                  FIM: TRANSFERS - TUB; SHOWER SCORE        101
# 64       FIM: SOCIAL COGNITION - PROBLEM SOLVING SCORE        101
# 69                       FIM: TRANSFERS - TOILET SCORE        101
# 55   FIM: LOCOMOTION - WALK/WHEELCHAIR SCORE (WALK ...         99
# 57                      FIM: SELF-CARE - BATHING SCORE         96
# 22                   ACO EXCLUSION.PREV.PNEUMO VACCINE         95
# 61                     FIM: SELF-CARE - GROOMING SCORE         90
# 59               FIM: SELF-CARE - DRESSING UPPER SCORE         88
# 63                FIM: SOCIAL COGNITION - MEMORY SCORE         83
# 65    FIM: SOCIAL COGNITION - SOCIAL INTERACTION SCORE         81
# 60                       FIM: SELF-CARE - EATING SCORE         78
# 54                      FIM: LOCOMOTION - STAIRS SCORE         70
# 104                                        WEIGHT (LB)         68
# 18                       ACO EXCLUSION.PREV.DEPRESSION         63
# 97                                         T-SCORE.HIP         56
# 67                FIM: SPHINCTER CONTROL - BOWEL SCORE         54
# 56   FIM: LOCOMOTION - WALK/WHEELCHAIR SCORE (WHEEL...         53
# 84                            PULMONARY FUNCTION TESTS         48
# 53   FIM: COMMUNICATION - EXPRESSION SCORE (VOCAL M...         44
# 48   FIM: COMMUNICATION - COMPREHENSION SCORE (AUDI...         42
# 50   FIM: COMMUNICATION - COMPREHENSION SCORE (VISU...         41
# 43                                       DYSPNEA_SCALE         36
# 52   FIM: COMMUNICATION - EXPRESSION SCORE (NON-VOC...         36
# 14   ACO 2015 EXCLUSION.DOCUMENTATION OF CURRENT ME...         31
# 51   FIM: COMMUNICATION - EXPRESSION SCORE (COMBINE...         30
# 49   FIM: COMMUNICATION - COMPREHENSION SCORE (COMB...         29
# 72                                        FVC_PCT_PRED         27
# 47                                       FEV1_PCT_PRED         26
# 83                  POST-PRANDIAL BLOOD GLUCOSE (PPBG)         26
# 86                                   PULSE.ORTHOSTATIC         23
# 95                                       T-SCORE.FEMUR         20
# 27                ACO.GERIATRIC DEPRESSION SCALE (GDS)         18
# 101                                      T-SCORE.WRIST         11
# 96                                     T-SCORE.FOREARM          6
# 17                      ACO EXCLUSION.PREV.COLONOSCOPY          6
# 100                                     T-SCORE.RADIUS          4
# 79                    MPHQ DEPRESSION SCREEN FOR TEENS          4
# 21                      ACO EXCLUSION.PREV.MAMMOGRAPHY          4
# 35                                ACT ASSESSMENT SCORE          2

# %%
## Only pick the top 15 "obs_type"

# %%
top_15_obs_type_list = df_obs_top_obstype_count.head(15)['obs_type'].to_list()

# %%
top_15_obs_type_list
# Out:
# ['SBP',
#  'DBP',
#  'PULSE',
#  'TEMP',
#  'RESP',
#  'BMI',
#  'WT',
#  'SMOKE',
#  'HT',
#  'HR',
#  'ALCOHOL',
#  'PAIN',
#  'ACO.TOBACCO USE',
#  'UROUT',
#  'PACK_YEARS']

# %%
df_obs_dedup_topObs = df_obs_dedup[df_obs_dedup['obs_type'].isin(top_15_obs_type_list)]

# %%
print(df_obs_dedup.shape)
print(df_obs_dedup_topObs.shape)
# Out:
# (5662458, 5)
# (5534168, 5)

# %%
df_obs_dedup_topObs.head()
# Out:
#        patientid obs_type obs_result obs_unit  days_to_covid_diag
# 0  RAADC3-364095      DBP         56    mm Hg                  12
# 1  RAADC3-364095      BMI       21.8     None                  12
# 2  RAADC3-364095    PULSE         72      bpm                  28
# 3  RAADC3-364095      SBP         95    mm Hg                  12
# 4  RAADC3-364095      DBP         58    mm Hg                  28

# %%
df_obs_dedup_topObs['obs_type_unit'] = df_obs_dedup_topObs['obs_type'].astype(str) + "(" \
+ df_obs_dedup_topObs['obs_unit'].astype(str) + ")"
# Out:
# /tmp/ipykernel_1659/2470226766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_obs_dedup_topObs['obs_type_unit'] = df_obs_dedup_topObs['obs_type'].astype(str) + "(" \

# %% [markdown]
# ### Understand the top 15 obs_types
# #### 1. SBP / DBP: blood pressure readings given in two numbers, top number is the max pressure, bottom number is the amount of pressure
# #### The definition of normal BP (systolic blood pressure [SBP] < 140 mmHg and diastolic blood pressure [DBP] < 90 mmHg) was first proposed by the 3rd report of Joint National committee on Detection, Evaluation and Treatment of High Blood Pressure in 1984 (JNC III)

# %%
df_obs_dedup_topObs_combined = df_obs_dedup_topObs[['patientid', 'obs_type_unit', 'obs_result', 'days_to_covid_diag']]

# %%
df_obs_dedup_topObs_combined.head()
# Out:
#        patientid obs_type_unit obs_result  days_to_covid_diag
# 0  RAADC3-364095    DBP(mm Hg)         56                  12
# 1  RAADC3-364095     BMI(None)       21.8                  12
# 2  RAADC3-364095    PULSE(bpm)         72                  28
# 3  RAADC3-364095    SBP(mm Hg)         95                  12
# 4  RAADC3-364095    DBP(mm Hg)         58                  28

# %%
df_obs_top_obstype_count.head(15)
# Out:
#             obs_type  patientid
# 89               SBP     908449
# 40               DBP     815406
# 85             PULSE     750610
# 102             TEMP     425857
# 87              RESP     411511
# 38               BMI     346390
# 105               WT     345327
# 91             SMOKE     324166
# 76                HT     265536
# 75                HR     243456
# 37           ALCOHOL     219053
# 81              PAIN     183940
# 34   ACO.TOBACCO USE     124593
# 103            UROUT     114996
# 80        PACK_YEARS      54878

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['patientid']=='RAADC3-364095'].\
sort_values(by='days_to_covid_diag')
# Out:
#         patientid      obs_type_unit obs_result  days_to_covid_diag
# 0   RAADC3-364095         DBP(mm Hg)         56                  12
# 1   RAADC3-364095          BMI(None)       21.8                  12
# 22  RAADC3-364095             WT(kg)      64.98                  12
# 3   RAADC3-364095         SBP(mm Hg)         95                  12
# 20  RAADC3-364095         SBP(mm Hg)        105                  21
# 18  RAADC3-364095        TEMP(deg c)       36.9                  21
# 15  RAADC3-364095         DBP(mm Hg)         67                  21
# 8   RAADC3-364095         PULSE(bpm)         73                  21
# 14  RAADC3-364095  RESP(breaths/min)         16                  21
# 19  RAADC3-364095             HT(cm)     172.72                  28
# 13  RAADC3-364095             WT(kg)      58.97                  28
# 24  RAADC3-364095          BMI(None)       19.8                  28
# 10  RAADC3-364095        TEMP(deg c)       36.7                  28
# 6   RAADC3-364095         SBP(mm Hg)         93                  28
# 4   RAADC3-364095         DBP(mm Hg)         58                  28
# 2   RAADC3-364095         PULSE(bpm)         72                  28
# 11  RAADC3-364095  RESP(breaths/min)         20                  28
# 23  RAADC3-364095             WT(kg)      60.95                  40
# 16  RAADC3-364095         DBP(mm Hg)         60                  40
# 5   RAADC3-364095          BMI(None)       20.4                  40
# 12  RAADC3-364095         SBP(mm Hg)        100                  40
# 9   RAADC3-364095         SBP(mm Hg)        102                  61
# 7   RAADC3-364095         DBP(mm Hg)         58                  61
# 17  RAADC3-364095          BMI(None)       19.7                  61
# 21  RAADC3-364095             WT(kg)      58.88                  61

# %%
df_obs_dedup_topObs_combined['obs_type_unit'].unique()
# Out:
# array(['DBP(mm Hg)', 'BMI(None)', 'PULSE(bpm)', 'SBP(mm Hg)',
#        'TEMP(deg c)', 'RESP(breaths/min)', 'WT(kg)', 'HT(cm)',
#        'SMOKE(None)', 'ALCOHOL(None)', 'HR(bpm)', 'UROUT(ml)',
#        'PAIN(out of 10)', 'ACO.TOBACCO USE(None)',
#        'PACK_YEARS(pack-years)'], dtype=object)

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='SMOKE(None)']
# Out:
#               patientid obs_type_unit         obs_result  days_to_covid_diag
# 25        RAADC3-026938   SMOKE(None)       Never smoked                  34
# 53        RAADC3-593426   SMOKE(None)       Never smoked                  35
# 64        RAADC3-042337   SMOKE(None)       Never smoked                  50
# 65        RAADC3-042337   SMOKE(None)       Never smoked                  13
# 93        RAADC3-461210   SMOKE(None)       Never smoked                  29
# ...                 ...           ...                ...                 ...
# 14734567  RAADC3-079138   SMOKE(None)       Never smoked                  49
# 14734576  RAADC3-265909   SMOKE(None)       Never smoked                  54
# 14734624  RAADC3-488203   SMOKE(None)  Previously smoked                  14
# 14734669  RAADC3-268628   SMOKE(None)  Previously smoked                  25
# 14734696  RAADC3-076415   SMOKE(None)       Never smoked                  43
#
# [324166 rows x 4 columns]

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='UROUT(ml)']
# Out:
#               patientid obs_type_unit obs_result  days_to_covid_diag
# 81        RAADC3-461210     UROUT(ml)        250                   2
# 2404      RAADC3-646894     UROUT(ml)       None                   1
# 3673      RAADC3-307110     UROUT(ml)        0.0                  33
# 3674      RAADC3-307110     UROUT(ml)        600                  33
# 3801      RAADC3-307110     UROUT(ml)       None                  33
# ...                 ...           ...        ...                 ...
# 14734125  RAADC3-205515     UROUT(ml)        100                  31
# 14734126  RAADC3-205515     UROUT(ml)        100                  32
# 14734256  RAADC3-488203     UROUT(ml)       1650                  38
# 14734314  RAADC3-205515     UROUT(ml)        900                  31
# 14734315  RAADC3-205515     UROUT(ml)        900                  32
#
# [114996 rows x 4 columns]

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='ACO.TOBACCO USE(None)']
# Out:
#               patientid          obs_type_unit        obs_result  \
# 1009      RAADC3-293562  ACO.TOBACCO USE(None)        3141.use.4
# 1013      RAADC3-293562  ACO.TOBACCO USE(None)    3141.tobuser.4
# 1014      RAADC3-293562  ACO.TOBACCO USE(None)  3141.smokeless.3
# 1053      RAADC3-293562  ACO.TOBACCO USE(None)  3141.smokeless.3
# 1060      RAADC3-293562  ACO.TOBACCO USE(None)        3141.use.4
# ...                 ...                    ...               ...
# 14734723  RAADC3-181324  ACO.TOBACCO USE(None)  3141.smokeless.3
# 14734739  RAADC3-346494  ACO.TOBACCO USE(None)  7789.smokeless.3
# 14734745  RAADC3-072789  ACO.TOBACCO USE(None)       10236.use.5
# 14734755  RAADC3-084140  ACO.TOBACCO USE(None)  4121.smokeless.3
# 14734775  RAADC3-169498  ACO.TOBACCO USE(None)    3141.tobuser.2
#
#           days_to_covid_diag
# 1009                      35
# 1013                       6
# 1014                      42
# 1053                      28
# 1060                       6
# ...                      ...
# 14734723                  51
# 14734739                  16
# 14734745                  53
# 14734755                   7
# 14734775                  22
#
# [124593 rows x 4 columns]

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='SMOKE(None)']
# Out:
#               patientid obs_type_unit         obs_result  days_to_covid_diag
# 25        RAADC3-026938   SMOKE(None)       Never smoked                  34
# 53        RAADC3-593426   SMOKE(None)       Never smoked                  35
# 64        RAADC3-042337   SMOKE(None)       Never smoked                  50
# 65        RAADC3-042337   SMOKE(None)       Never smoked                  13
# 93        RAADC3-461210   SMOKE(None)       Never smoked                  29
# ...                 ...           ...                ...                 ...
# 14734567  RAADC3-079138   SMOKE(None)       Never smoked                  49
# 14734576  RAADC3-265909   SMOKE(None)       Never smoked                  54
# 14734624  RAADC3-488203   SMOKE(None)  Previously smoked                  14
# 14734669  RAADC3-268628   SMOKE(None)  Previously smoked                  25
# 14734696  RAADC3-076415   SMOKE(None)       Never smoked                  43
#
# [324166 rows x 4 columns]

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='PAIN(out of 10)']
# Out:
#               patientid    obs_type_unit obs_result  days_to_covid_diag
# 108       RAADC3-461210  PAIN(out of 10)          5                   2
# 135       RAADC3-461210  PAIN(out of 10)          2                  29
# 141       RAADC3-461210  PAIN(out of 10)          4                   2
# 194       RAADC3-461210  PAIN(out of 10)          6                   2
# 267       RAADC3-461210  PAIN(out of 10)        4.5                  23
# ...                 ...              ...        ...                 ...
# 14733550  RAADC3-265909  PAIN(out of 10)          5                  60
# 14733880  RAADC3-083856  PAIN(out of 10)         10                  31
# 14734032  RAADC3-038276  PAIN(out of 10)          0                   9
# 14734087  RAADC3-256859  PAIN(out of 10)        8.0                  43
# 14734600  RAADC3-723995  PAIN(out of 10)        6.0                   1
#
# [183940 rows x 4 columns]

# %%
df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined['obs_type_unit']=='PACK_YEARS(pack-years)']
# Out:
#               patientid           obs_type_unit obs_result  days_to_covid_diag
# 1262      RAADC3-190508  PACK_YEARS(pack-years)         .5                  13
# 1264      RAADC3-027277  PACK_YEARS(pack-years)         30                   4
# 1655      RAADC3-206530  PACK_YEARS(pack-years)          3                  57
# 1677      RAADC3-206530  PACK_YEARS(pack-years)          3                  28
# 1693      RAADC3-597597  PACK_YEARS(pack-years)         12                   6
# ...                 ...                     ...        ...                 ...
# 14733296  RAADC3-338275  PACK_YEARS(pack-years)        5.5                  20
# 14734046  RAADC3-057271  PACK_YEARS(pack-years)          1                  13
# 14734298  RAADC3-294499  PACK_YEARS(pack-years)       1.25                  41
# 14734363  RAADC3-228214  PACK_YEARS(pack-years)         45                  23
# 14734425  RAADC3-228214  PACK_YEARS(pack-years)         45                  55
#
# [54878 rows x 4 columns]

# %% [markdown]
# ### BMI
# ### df_obs_patient_BMI_max

# %%
df_obs_dedup_topObs_BMI = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='BMI(None)'].dropna()

# %%
df_obs_dedup_topObs_BMI.head()
# Out:
#         patientid obs_type_unit obs_result  days_to_covid_diag
# 1   RAADC3-364095     BMI(None)       21.8                  12
# 5   RAADC3-364095     BMI(None)       20.4                  40
# 17  RAADC3-364095     BMI(None)       19.7                  61
# 24  RAADC3-364095     BMI(None)       19.8                  28
# 30  RAADC3-586023     BMI(None)       33.3                  20

# %%
df_obs_dedup_topObs_BMI.obs_result.unique()
# Out:
# array(['21.8', '20.4', '19.7', '19.8', '33.3', '33.5', '53.7', '22.5',
#        '31.4', '29.7', '32.6', '30.9', '34.9', '36.2', '40.3', '40.4',
#        '23.8', '23.3', '23.4', '17.9', '43.7', '36.6', '27.3', '33.0',
#        '34.0', '34.2', '37.1', '38.2', '34.7', '22.2', '22.0', '22',
#        '30.6', '35.9', '68.2', '67.8', '26.2', '28.8', '28.9', '28.2',
#        '28.7', '29.0', '28.5', '26.3', '38.6', '32.3', '32.1', '31.2',
#        '32', '33.1', '26.4', '27.7', '44.5', '44.2', '32.0', '30.7',
#        '31.5', '33.2', '21.4', '22.3', '28.6', '43.8', '38.3', '43.4',
#        '25.4', '33.4', '35', '35.0', '25.6', '45.2', '35.7', '38.8',
#        '46.8', '41.5', '21.5', '26.0', '26', '27.2', '27', '31.0', '30.4',
#        '30.2', '24.8', '25.2', '25.1', '31', '25.8', '23.0', '25.3', '23',
#        '24.9', '27.5', '27.8', '20.8', '29', '33', '26.6', '32.9', '33.8',
#        '34', '22.8', '18.8', '45.4', '45.0', '45', '39.7', '39.8', '43.5',
#        '42.0', '43', '43.0', '41.1', '42', '30', '43.1', '19.9', '30.1',
#        '36.3', '30.8', '21.3', '36.4', '25.7', '40.9', '60.1', '40.7',
#        '40', '40.0', '29.8', '54.3', '53.8', '55.4', '28.4', '31.1', '39',
#        '38.4', '39.0', '28.3', '27.9', '34.3', '24.7', '32.4', '34.8',
#        '32.5', '32.2', '36', '36.0', '35.8', '28.1', '27.1', '23.7',
#        '44.3', '44.4', '43.9', '26.5', '20.7', '21.7', '29.2', '29.1',
#        '31.6', '22.6', '20.5', '33.6', '32.8', '32.7', '42.9', '35.1',
#        '42.1', '42.3', '41.7', '41.8', '24.5', '39.1', '38.9', '37.9',
#        '37.5', '37.2', '46.9', '31.7', '41', '41.0', '44.9', '43.3',
#        '31.9', '19.2', '21.6', '31.8', '55.3', '21.1', '41.3', '38.5',
#        '39.3', '23.2', '23.5', '22.9', '26.9', '34.6', '23.9', '34.5',
#        '30.5', '33.7', '56', '56.0', '49.4', '23.6', '20.3', '35.3',
#        '54.2', '49.8', '51.2', '49.7', '47.6', '21.2', '20.9', '29.6',
#        '35.5', '39.2', '30.0', '45.5', '25', '24.4', '27.4', '27.0',
#        '35.4', '47.2', '26.7', '42.5', '22.4', '38.7', '39.9', '20.1',
#        '47.5', '39.5', '36.8', '29.5', '36.7', '37', '31.3', '40.5',
#        '40.6', '34.1', '24.1', '26.1', '36.1', '60.8', '37.4', '46.1',
#        '39.4', '24.3', '17.6', '17.8', '18.2', '44.6', '45.1', '41.2',
#        '48.8', '18.9', '24.6', '25.9', '19.5', '27.6', '70.4', '70.9',
#        '69.3', '68.8', '20.2', '23.1', '36.9', '35.6', '48.1', '24.2',
#        '34.4', '50.3', '50.4', '50.9', '50.5', '50.1', '50.0', '50.6',
#        '38', '37.7', '54.1', '53.0', '53', '28', '28.0', '20', '20.0',
#        '49.2', '49', '47.1', '50.2', '49.0', '29.9', '29.3', '53.2',
#        '66.9', '67.4', '61.6', '25.5', '33.9', '39.6', '30.3', '45.6',
#        '54.8', '54.9', '42.7', '36.5', '37.6', '42.4', '40.8', '18.7',
#        '18.4', '18.6', '17.0', '19.4', '17.7', '17', '42.2', '16.6',
#        '22.1', '49.3', '48.3', '38.1', '24', '48.6', '49.9', '46.5',
#        '35.2', '43.2', '22.7', '44.8', '21', '21.0', '14.7', '29.4',
#        '46.4', '52', '49.1', '18.5', '24.0', '69.9', '51.7', '52.2',
#        '52.1', '62', '21.9', '45.8', '72.8', '48', '48.0', '46.7', '58.5',
#        '50', '50.7', '26.8', '41.6', '53.3', '52.8', '53.1', '59.1',
#        '25.0', '37.0', '14.4', '41.9', '48.7', '52.6', '52.3', '52.7',
#        '20.6', '47.3', '44', '44.0', '18.3', '47', '47.0', '42.8', '37.3',
#        '40.2', '45.7', '37.8', '64.2', '64.3', '51.5', '51.6', '48.2',
#        '49.6', '57.1', '57', '45.9', '19.1', '61.5', '61.1', '62.0',
#        '70.5', '66.6', '15.2', '15.6', '14.5', '14', '15.4', '14.9',
#        '17.2', '14.0', '14.8', '14.6', '14.3', '15.5', '11.3', '15.3',
#        '15.7', '15.8', '15.9', '14.2', '43.6', '38.0', '51.4', '19.6',
#        '17.5', '16.3', '17.4', '69.8', '40.1', '47.9', '64.1', '16.9',
#        '52.9', '48.4', '18.1', '18.0', '18', '46.3', '46', '57.8', '57.0',
#        '58.3', '58.2', '58.1', '57.5', '55.6', '17.3', '59.9', '41.4',
#        '51', '51.0', '56.4', '67.6', '16.5', '42.6', '48.5', '50.8',
#        '16.7', '47.7', '47.4', '19.0', '19', '16', '16.0', '46.2', '16.8',
#        '14.1', '19.3', '44.7', '66.7', '59.3', '51.8', '55.0', '55.8',
#        '45.3', '56.8', '51.1', '46.0', '44.1', '57.7', '58.9', '57.4',
#        '62.8', '62.7', '71.2', '71.4', '53.9', '55.1', '49.5', '47.8',
#        '46.6', '56.2', '55.7', '54.0', '56.1', '54.6', '56.3', '48.9',
#        '51.9', '52.0', '52.5', '63.5', '62.1', '63.8', '60.9', '17.1',
#        '57.3', '16.4', '53.5', '60.2', '60.3', '60.7', '63.1', '16.1',
#        '66.3', '66.4', '59.7', '59.8', '60', '61.8', '59.5', '59.2',
#        '59.6', '57.9', '69.4', '65.5', '63.2', '61.4', '53.6', '63',
#        '63.0', '58.7', '54', '65.1', '73.1', '57.6', '56.7', '55.9',
#        '58.8', '59.0', '56.5', '56.6', '134.4', '52.4', '66.5', '63.7',
#        '65.6', '65.4', '62.5', '62.6', '61.9', '54.4', '61.0', '61',
#        '62.3', '60.0', '55.2', '59.4', '60.6', '66.1', '68.7', '68.0',
#        '68.9', '63.3', '63.4', '61.3', '56.9', '60.5', '10.6', '70.0',
#        '70.1', '74.7', '74.0', '74.4', '65.2', '74.5', '9.4', '13.0',
#        '15.0', '13', '15.1', '13.6', '15', '54.5', '16.2', '58.6', '63.6',
#        '63.9', '51.3', '74.8', '8.3', '12.9', '64.8', '62.9', '13.9',
#        '53.4', '79.2', '78.0', '79.0', '73.2', '74.2', '76.2', '71.9',
#        '91.8', '92.5', '91.2', '65.7', '62.2', '55.5', '54.7', '55',
#        '67.7', '67.5', '69.2', '67.3', '67.2', '64.4', '68.1', '62.4',
#        '61.2', '68.4', '70.3', '65.9', '71.5', '70.7', '70.8', '71.6',
#        '57.2', '82.5', '79.6', '83.3', '75.1', '58', '59', '65', '73.7',
#        '67.0', '65.8', '64.7', '74.6', '13.4', '13.3', '58.0', '66.8',
#        '75.4', '9', '9.0', '12.7', '60.4', '69.7', '64.6', '70.2', '75',
#        '75.2', '74.9', '75.6', '72.3', '76', '72.5', '68.5', '70.6',
#        '61.7', '68.3', '68', '58.4', '13.8', '12.6', '78.9', '71.8', '81',
#        '79.5', '79.3', '78.7', '73.9', '67.1', '72.6', '72.2', '77.4',
#        '80.1', '81.5', '71.3', '81.9', '77.6', '69.0', '79.4', '77.9',
#        '80.3', '79.1', '78.8', '77.2', '80.6', '77.5', '82.4', '80.9',
#        '82.7', '79.7', '72.7', '76.8', '78.1', '77.3', '69', '80', '77.0',
#        '77.8', '73.6', '78.3', '71', '77', '72.1', '81.1', '81.6', '80.0',
#        '78', '81.0', '8.5', '107.3', '107.2', '106.3', '107.7', '106.4',
#        '106.2', '107.4', '65.0', '87.7', '87.9', '87.8', '86.7', '85.9',
#        '69.5', '75.0', '64.0', '64', '67.9', '67', '84.8', '10.2', '13.2',
#        '10.3', '110.6', '13.1', '69.6', '66', '66.0', '71.0', '64.9',
#        '13.7', '73.3', '64.5', '73.5', '69.1', '68.6', '81.3', '66.2',
#        '115.2', '11.5', '86.1', '11.4', '172.2', '7.1', '10.9', '12',
#        '12.0', '8.2', '76.9', '13.5', '72.9', '156.3', '96.2', '93.8',
#        '93.1', '93.3', '90.4', '71.7', '77.7', '12.5', '81.4', '75.5',
#        '11.9', '73.4', '73.8', '84.4', '84.2', '81.7', '77.1', '99.8',
#        '99.9', '74.3', '75.3', '76.7', '76.3', '76.4', '74.1', '65.3',
#        '96.9', '70', '89.4', '84.3', '99', '83.6', '86.8', '80.2', '78.6',
#        '75.7', '75.8', '74', '76.6', '73', '90.9', '7.3', '98.8', '107.5',
#        '98.7', '88.4', '97.8', '97.9', '10.0', '85.8', '91.0', '91.1',
#        '9.2', '78.4', '9.7', '9.6', '11.6', '89.6', '75.9', '76.1',
#        '98.9', '80.7', '78.5', '80.8', '79', '76.5', '79.8', '81.2',
#        '110.1', '78.2', '12.8', '86.2', '82.6', '82.3', '95.2', '10.5',
#        '84', '98.6', '84.0', '11.2', '93.0', '88.3', '12.3', '8.7',
#        '83.1', '100.2', '93', '72.4', '108.7', '96.1', '96', '96.0',
#        '135.7', '135.8', '149.5', '180.6', '72.0', '72', '82.9', '71.1'],
#       dtype=object)

# %%
df_obs_patient_BMI_max = df_obs_dedup_topObs_BMI.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_patient_BMI_max.columns = ['patientid', 'BMI_max']

# %%
df_obs_patient_BMI_max.head()
# Out:
#        patientid BMI_max
# 0  RAADC3-000005    31.7
# 1  RAADC3-000006    25.2
# 2  RAADC3-000009    30.2
# 3  RAADC3-000011    27.9
# 4  RAADC3-000013    20.8

# %% [markdown]
# ### HT
# ### df_obs_dedup_topObs_HT_max
# ### WT
# ### df_obs_dedup_topObs_WT_max

# %%
df_obs_dedup_topObs_HT = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='HT(cm)'].dropna()

df_obs_dedup_topObs_HT_max = df_obs_dedup_topObs_HT.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_HT_max.columns = ['patientid', 'HT_max']

# %%
df_obs_dedup_topObs_HT_max.head()
# Out:
#        patientid  HT_max
# 0  RAADC3-000006  162.56
# 1  RAADC3-000008  142.24
# 2  RAADC3-000009  160.02
# 3  RAADC3-000011   152.4
# 4  RAADC3-000013  170.18

# %%
df_obs_dedup_topObs_WT = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='WT(kg)'].dropna()

df_obs_dedup_topObs_WT_max = df_obs_dedup_topObs_WT.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_WT_max.columns = ['patientid', 'WT_max']

# %%
df_obs_dedup_topObs_WT_max.head()
# Out:
#        patientid WT_max
# 0  RAADC3-000005   72.3
# 1  RAADC3-000006  66.68
# 2  RAADC3-000009  77.22
# 3  RAADC3-000011  64.86
# 4  RAADC3-000013  60.33

# %% [markdown]
# ### Pulse
# ### df_obs_dedup_topObs_PULSE_max
# ### TEMP
# ### df_obs_dedup_topObs_TEMP_max
# ### RESP
# ### df_obs_dedup_topObs_RESP_max
# ### HR
# ### df_obs_dedup_topObs_HR_max

# %%
df_obs_dedup_topObs_PULSE = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='PULSE(bpm)'].dropna()

df_obs_dedup_topObs_PULSE_max = df_obs_dedup_topObs_PULSE.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_PULSE_max.columns = ['patientid', 'PULSE_max']

# %%
df_obs_dedup_topObs_PULSE_max.head()
# Out:
#        patientid PULSE_max
# 0  RAADC3-000005        70
# 1  RAADC3-000006        83
# 2  RAADC3-000009        85
# 3  RAADC3-000011        77
# 4  RAADC3-000018        82

# %%
df_obs_dedup_topObs_TEMP = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='TEMP(deg c)'].dropna()

df_obs_dedup_topObs_TEMP_max = df_obs_dedup_topObs_TEMP.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_TEMP_max.columns = ['patientid', 'TEMP_max']

# %%
df_obs_dedup_topObs_TEMP_max.head()
# Out:
#        patientid TEMP_max
# 0  RAADC3-000009     37.1
# 1  RAADC3-000011     36.5
# 2  RAADC3-000013     36.7
# 3  RAADC3-000018     36.8
# 4  RAADC3-000019     36.9

# %%
df_obs_dedup_topObs_RESP = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='RESP(breaths/min)'].dropna()

df_obs_dedup_topObs_RESP_max = df_obs_dedup_topObs_RESP.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_RESP_max.columns = ['patientid', 'RESP_max']

# %%
df_obs_dedup_topObs_RESP_max.head()
# Out:
#        patientid RESP_max
# 0  RAADC3-000009     20.0
# 1  RAADC3-000018       18
# 2  RAADC3-000024     20.0
# 3  RAADC3-000036     16.0
# 4  RAADC3-000045     20.0

# %%
df_obs_dedup_topObs_HR = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='HR(bpm)'].dropna()

df_obs_dedup_topObs_HR_max = df_obs_dedup_topObs_HR.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_HR_max.columns = ['patientid', 'HR_max']

# %%
df_obs_dedup_topObs_HR_max.head()
# Out:
#        patientid HR_max
# 0  RAADC3-000051     88
# 1  RAADC3-000055     88
# 2  RAADC3-000073     97
# 3  RAADC3-000130     61
# 4  RAADC3-000131     99

# %% [markdown]
# ## Inspect tables
# ## Inconsistent records per patientid
#
# ### SMOKE
# ### df_obs_dedup_topObs_SMOKE
# ### ALCOHOL
# ### df_obs_dedup_topObs_ALCOHOL

# %%
df_obs_dedup_topObs_SMOKE = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='SMOKE(None)']\
[['patientid', 'obs_result']].drop_duplicates().reset_index(drop=True)

df_obs_dedup_topObs_SMOKE.columns = ['patientid', 'SMOKE']

# %%
df_obs_dedup_topObs_SMOKE.head()
# Out:
#        patientid         SMOKE
# 0  RAADC3-026938  Never smoked
# 1  RAADC3-593426  Never smoked
# 2  RAADC3-042337  Never smoked
# 3  RAADC3-461210  Never smoked
# 4  RAADC3-326688  Never smoked

# %%
df_obs_smoke_count = df_obs_dedup_topObs_SMOKE.groupby('patientid')[['SMOKE']].count().\
reset_index().sort_values(by='SMOKE', ascending=False)

smoke_inconsistent_to_drop = df_obs_smoke_count[df_obs_smoke_count['SMOKE']!=1]['patientid'].to_list()

print(len(smoke_inconsistent_to_drop))
# Out:
# 25233

# %%
print(df_obs_dedup_topObs_SMOKE.shape)
df_obs_dedup_topObs_SMOKE_dedup = df_obs_dedup_topObs_SMOKE[~df_obs_dedup_topObs_SMOKE['patientid'].\
                                                      isin(smoke_inconsistent_to_drop)]

print(df_obs_dedup_topObs_SMOKE_dedup.shape)
# Out:
# (172262, 2)
# (118280, 2)

# %%
df_obs_dedup_topObs_SMOKE[df_obs_dedup_topObs_SMOKE['patientid']=='RAADC3-000013']
# Out:
#             patientid                  SMOKE
# 101416  RAADC3-000013  Not currently smoking
# 101417  RAADC3-000013         Current smoker
# 101418  RAADC3-000013           Never smoked

# %%
df_obs_dedup_topObs_SMOKE.groupby('patientid')[['SMOKE']].count().\
reset_index().sort_values(by='patientid', ascending=True)
# Out:
#             patientid  SMOKE
# 0       RAADC3-000005      1
# 1       RAADC3-000006      1
# 2       RAADC3-000008      1
# 3       RAADC3-000011      1
# 4       RAADC3-000013      3
# ...               ...    ...
# 143507  RAADC3-727950      1
# 143508  RAADC3-727953      1
# 143509  RAADC3-727954      1
# 143510  RAADC3-727956      1
# 143511  RAADC3-727960      1
#
# [143512 rows x 2 columns]

# %%
len(df_obs_dedup_topObs_SMOKE['patientid'].unique())
# Out:
# 143513

# %%
df_obs_dedup_topObs_ALCOHOL = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='ALCOHOL(None)'].dropna()\
[['patientid', 'obs_result']].drop_duplicates().reset_index(drop=True)

df_obs_dedup_topObs_ALCOHOL.columns = ['patientid', 'ALCOHOL']

# %%
df_obs_dedup_topObs_ALCOHOL.head()
# Out:
#        patientid                      ALCOHOL
# 0  RAADC3-593426  Unknown alcohol consumption
# 1  RAADC3-593426             Consumes alcohol
# 2  RAADC3-326688             Consumes alcohol
# 3  RAADC3-230262     Does not consume alcohol
# 4  RAADC3-098476             Consumes alcohol

# %%
df_obs_alcohol_count = df_obs_dedup_topObs_ALCOHOL.groupby('patientid')[['ALCOHOL']].count().\
reset_index().sort_values(by='ALCOHOL', ascending=False)

alcohol_inconsistent_to_drop = df_obs_alcohol_count[df_obs_alcohol_count['ALCOHOL']!=1]['patientid'].to_list()

print(len(alcohol_inconsistent_to_drop))
# Out:
# 15061

# %%
print(df_obs_dedup_topObs_ALCOHOL.shape)
df_obs_dedup_topObs_ALCOHOL_dedup = df_obs_dedup_topObs_ALCOHOL[~df_obs_dedup_topObs_ALCOHOL['patientid'].\
                                                      isin(alcohol_inconsistent_to_drop)]

print(df_obs_dedup_topObs_ALCOHOL_dedup.shape)
# Out:
# (109590, 2)
# (78943, 2)

# %% [markdown]
# ### PAIN
# ### df_obs_dedup_topObs_PAIN_max
# ### Pack-year
# ### df_obs_dedup_topObs_PACKYRS_max

# %%
df_obs_dedup_topObs_PAIN = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='PAIN(out of 10)'].dropna()

df_obs_dedup_topObs_PAIN_max = df_obs_dedup_topObs_PAIN.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_PAIN_max.columns = ['patientid', 'PAIN_max']

# %%
df_obs_dedup_topObs_PAIN.head()
# Out:
#          patientid    obs_type_unit obs_result  days_to_covid_diag
# 108  RAADC3-461210  PAIN(out of 10)          5                   2
# 135  RAADC3-461210  PAIN(out of 10)          2                  29
# 141  RAADC3-461210  PAIN(out of 10)          4                   2
# 194  RAADC3-461210  PAIN(out of 10)          6                   2
# 267  RAADC3-461210  PAIN(out of 10)        4.5                  23

# %%
df_obs_dedup_topObs_PACKYRS = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='PACK_YEARS(pack-years)'].dropna()

df_obs_dedup_topObs_PACKYRS_max = df_obs_dedup_topObs_PACKYRS.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_PACKYRS_max.columns = ['patientid', 'PACKYRS_max']

# %%
df_obs_dedup_topObs_PACKYRS_max.head()
# Out:
#        patientid PACKYRS_max
# 0  RAADC3-000008           0
# 1  RAADC3-000013           0
# 2  RAADC3-000044           0
# 3  RAADC3-000062          40
# 4  RAADC3-000066           0

# %% [markdown]
# ### DBP
# ### df_obs_dedup_topObs_DBP_max
# ### SBP
# ### df_obs_dedup_topObs_SBP_max

# %%
df_obs_dedup_topObs_DBP = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='DBP(mm Hg)'].dropna()

df_obs_dedup_topObs_DBP_max = df_obs_dedup_topObs_DBP.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_DBP_max.columns = ['patientid', 'DBP_max']

# %%
df_obs_dedup_topObs_DBP_max.head()
# Out:
#        patientid DBP_max
# 0  RAADC3-000005      80
# 1  RAADC3-000006      72
# 2  RAADC3-000009      70
# 3  RAADC3-000011      74
# 4  RAADC3-000013      80

# %%
df_obs_dedup_topObs_SBP = df_obs_dedup_topObs_combined[df_obs_dedup_topObs_combined\
                                                       ['obs_type_unit']=='SBP(mm Hg)'].dropna()

df_obs_dedup_topObs_SBP_max = df_obs_dedup_topObs_SBP.groupby('patientid')[['obs_result']]\
.max().reset_index().sort_values(by='patientid')

df_obs_dedup_topObs_SBP_max.columns = ['patientid', 'SBP_max']

# %%
df_obs_dedup_topObs_SBP_max.head()
# Out:
#        patientid SBP_max
# 0  RAADC3-000005     138
# 1  RAADC3-000006     144
# 2  RAADC3-000009     130
# 3  RAADC3-000011     160
# 4  RAADC3-000013     122

# %% [markdown]
# ## Aggregation of all tables after pivot and clean

# %%
### Each patient may have multiple observations over the visits. 
### For BMI: take max (done)
### For WT/HT: take max (done)
### For DBP/SBP: take highest (high BP), categorize
### For Pulse: take highest (done)
### For TEMP/RESP/HR: take highest (done)
### For SMOKE, Alcohol: drop duplicates (done)
### For ACO.TOBACCO USE (do not include)
### For PAIN: the the value from 1-10 (take max) (done)
### For Pack-year: take the value (done)


df_obs_dedup_topObs_combined['obs_type_unit'].unique()
# Out:
# array(['DBP(mm Hg)', 'BMI(None)', 'PULSE(bpm)', 'SBP(mm Hg)',
#        'TEMP(deg c)', 'RESP(breaths/min)', 'WT(kg)', 'HT(cm)',
#        'SMOKE(None)', 'ALCOHOL(None)', 'HR(bpm)', 'UROUT(ml)',
#        'PAIN(out of 10)', 'ACO.TOBACCO USE(None)',
#        'PACK_YEARS(pack-years)'], dtype=object)

# %%
df_obs_dedup_topObs_SMOKE.shape
# Out:
# (172262, 2)

# %%
df_obs_dedup_topObs_ALCOHOL.shape
# Out:
# (109590, 2)

# %%
obs_table_list = [df_obs_patient_BMI_max, df_obs_dedup_topObs_HT_max, df_obs_dedup_topObs_WT_max, \
                 df_obs_dedup_topObs_PULSE_max, df_obs_dedup_topObs_TEMP_max, df_obs_dedup_topObs_RESP_max, \
                 df_obs_dedup_topObs_HR_max, \
                 df_obs_dedup_topObs_PAIN_max, df_obs_dedup_topObs_PACKYRS_max, \
                 df_obs_dedup_topObs_DBP_max, df_obs_dedup_topObs_SBP_max, \
                 df_obs_dedup_topObs_SMOKE_dedup, df_obs_dedup_topObs_ALCOHOL_dedup]

# %%
df_obs_pid_for_left_merge = df_obs_dedup_topObs_combined[['patientid']].drop_duplicates()
df_obs_pid_for_left_merge['status'] ='PT_with_OBS'

# %%
df_obs_pid_for_left_merge.head()
# Out:
#         patientid       status
# 0   RAADC3-364095  PT_with_OBS
# 25  RAADC3-026938  PT_with_OBS
# 27  RAADC3-586023  PT_with_OBS
# 42  RAADC3-593426  PT_with_OBS
# 63  RAADC3-042337  PT_with_OBS

# %%
df_obs_pid_for_left_merge.shape
# Out:
# (178952, 2)

# %%
df_obs_patient_BMI_max.head()
# Out:
#        patientid BMI_max
# 0  RAADC3-000005    31.7
# 1  RAADC3-000006    25.2
# 2  RAADC3-000009    30.2
# 3  RAADC3-000011    27.9
# 4  RAADC3-000013    20.8

# %%
print(df_obs_patient_BMI_max.shape)
print(df_obs_patient_BMI_max.drop_duplicates().shape)
# Out:
# (144702, 2)
# (144702, 2)

# %%
df = df_obs_pid_for_left_merge
print(df.head())
# Out:
#         patientid       status
# 0   RAADC3-364095  PT_with_OBS
# 25  RAADC3-026938  PT_with_OBS
# 27  RAADC3-586023  PT_with_OBS
# 42  RAADC3-593426  PT_with_OBS
# 63  RAADC3-042337  PT_with_OBS

# %%
df_obs_pid_for_left_merge.head()
# Out:
#         patientid       status
# 0   RAADC3-364095  PT_with_OBS
# 25  RAADC3-026938  PT_with_OBS
# 27  RAADC3-586023  PT_with_OBS
# 42  RAADC3-593426  PT_with_OBS
# 63  RAADC3-042337  PT_with_OBS

# %%
df_obs_pid_for_left_merge.merge(df_obs_patient_BMI_max, on='patientid', how='left')
# Out:
#             patientid       status BMI_max
# 0       RAADC3-364095  PT_with_OBS    21.8
# 1       RAADC3-026938  PT_with_OBS     NaN
# 2       RAADC3-586023  PT_with_OBS    33.5
# 3       RAADC3-593426  PT_with_OBS    53.7
# 4       RAADC3-042337  PT_with_OBS    22.5
# ...               ...          ...     ...
# 178947  RAADC3-260173  PT_with_OBS     NaN
# 178948  RAADC3-529851  PT_with_OBS     NaN
# 178949  RAADC3-642887  PT_with_OBS     NaN
# 178950  RAADC3-251634  PT_with_OBS     NaN
# 178951  RAADC3-251805  PT_with_OBS     NaN
#
# [178952 rows x 3 columns]

# %%
## left merge

df = df_obs_pid_for_left_merge
for obs_ind_table in obs_table_list:
    print("shape of the table to be merged", obs_ind_table.shape)
    print(obs_ind_table.head())
    df = df.merge(obs_ind_table, on='patientid', how='left').sort_values(by='patientid')
    print("shape of intermediate table", df.shape)
    print(df.head())
    print("========")
# Out:
# shape of the table to be merged (144702, 2)
#        patientid BMI_max
# 0  RAADC3-000005    31.7
# 1  RAADC3-000006    25.2
# 2  RAADC3-000009    30.2
# 3  RAADC3-000011    27.9
# 4  RAADC3-000013    20.8
# shape of intermediate table (178952, 3)
#             patientid       status BMI_max
# 18496   RAADC3-000002  PT_with_OBS     NaN
# 114966  RAADC3-000005  PT_with_OBS    31.7
# 1620    RAADC3-000006  PT_with_OBS    25.2
# 161696  RAADC3-000008  PT_with_OBS     NaN
# 127635  RAADC3-000009  PT_with_OBS    30.2
# ========
# shape of the table to be merged (135957, 2)
#        patientid  HT_max
# 0  RAADC3-000006  162.56
# 1  RAADC3-000008  142.24
# 2  RAADC3-000009  160.02
# 3  RAADC3-000011   152.4
# 4  RAADC3-000013  170.18
# shape of intermediate table (178952, 4)
#        patientid       status BMI_max  HT_max
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02
# ========
# shape of the table to be merged (144284, 2)
#        patientid WT_max
# 0  RAADC3-000005   72.3
# 1  RAADC3-000006  66.68
# 2  RAADC3-000009  77.22
# 3  RAADC3-000011  64.86
# 4  RAADC3-000013  60.33
# shape of intermediate table (178952, 5)
#        patientid       status BMI_max  HT_max WT_max
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22
# ========
# shape of the table to be merged (127406, 2)
#        patientid PULSE_max
# 0  RAADC3-000005        70
# 1  RAADC3-000006        83
# 2  RAADC3-000009        85
# 3  RAADC3-000011        77
# 4  RAADC3-000018        82
# shape of intermediate table (178952, 6)
#        patientid       status BMI_max  HT_max WT_max PULSE_max
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85
# ========
# shape of the table to be merged (124935, 2)
#        patientid TEMP_max
# 0  RAADC3-000009     37.1
# 1  RAADC3-000011     36.5
# 2  RAADC3-000013     36.7
# 3  RAADC3-000018     36.8
# 4  RAADC3-000019     36.9
# shape of intermediate table (178952, 7)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
# ========
# shape of the table to be merged (93417, 2)
#        patientid RESP_max
# 0  RAADC3-000009     20.0
# 1  RAADC3-000018       18
# 2  RAADC3-000024     20.0
# 3  RAADC3-000036     16.0
# 4  RAADC3-000045     20.0
# shape of intermediate table (178952, 8)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4     20.0
# ========
# shape of the table to be merged (23663, 2)
#        patientid HR_max
# 0  RAADC3-000051     88
# 1  RAADC3-000055     88
# 2  RAADC3-000073     97
# 3  RAADC3-000130     61
# 4  RAADC3-000131     99
# shape of intermediate table (178952, 9)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4     20.0    NaN
# ========
# shape of the table to be merged (54736, 2)
#        patientid PAIN_max
# 0  RAADC3-000002        2
# 1  RAADC3-000006        0
# 2  RAADC3-000008        0
# 3  RAADC3-000011        0
# 4  RAADC3-000013        5
# shape of intermediate table (178952, 10)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max
# 0      NaN    NaN        2
# 1      NaN    NaN      NaN
# 2      NaN    NaN        0
# 3      NaN    NaN        0
# 4     20.0    NaN      NaN
# ========
# shape of the table to be merged (21622, 2)
#        patientid PACKYRS_max
# 0  RAADC3-000008           0
# 1  RAADC3-000013           0
# 2  RAADC3-000044           0
# 3  RAADC3-000062          40
# 4  RAADC3-000066           0
# shape of intermediate table (178952, 11)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max PACKYRS_max
# 0      NaN    NaN        2         NaN
# 1      NaN    NaN      NaN         NaN
# 2      NaN    NaN        0         NaN
# 3      NaN    NaN        0           0
# 4     20.0    NaN      NaN         NaN
# ========
# shape of the table to be merged (138186, 2)
#        patientid DBP_max
# 0  RAADC3-000005      80
# 1  RAADC3-000006      72
# 2  RAADC3-000009      70
# 3  RAADC3-000011      74
# 4  RAADC3-000013      80
# shape of intermediate table (178952, 12)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max PACKYRS_max DBP_max
# 0      NaN    NaN        2         NaN     NaN
# 1      NaN    NaN      NaN         NaN      80
# 2      NaN    NaN        0         NaN      72
# 3      NaN    NaN        0           0     NaN
# 4     20.0    NaN      NaN         NaN      70
# ========
# shape of the table to be merged (138048, 2)
#        patientid SBP_max
# 0  RAADC3-000005     138
# 1  RAADC3-000006     144
# 2  RAADC3-000009     130
# 3  RAADC3-000011     160
# 4  RAADC3-000013     122
# shape of intermediate table (178952, 13)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max PACKYRS_max DBP_max SBP_max
# 0      NaN    NaN        2         NaN     NaN     NaN
# 1      NaN    NaN      NaN         NaN      80     138
# 2      NaN    NaN        0         NaN      72     144
# 3      NaN    NaN        0           0     NaN     NaN
# 4     20.0    NaN      NaN         NaN      70     130
# ========
# shape of the table to be merged (118280, 2)
#        patientid         SMOKE
# 0  RAADC3-026938  Never smoked
# 1  RAADC3-593426  Never smoked
# 2  RAADC3-042337  Never smoked
# 3  RAADC3-461210  Never smoked
# 4  RAADC3-326688  Never smoked
# shape of intermediate table (178952, 14)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max PACKYRS_max DBP_max SBP_max         SMOKE
# 0      NaN    NaN        2         NaN     NaN     NaN           NaN
# 1      NaN    NaN      NaN         NaN      80     138  Never smoked
# 2      NaN    NaN        0         NaN      72     144  Never smoked
# 3      NaN    NaN        0           0     NaN     NaN  Never smoked
# 4     20.0    NaN      NaN         NaN      70     130           NaN
# ========
# shape of the table to be merged (78943, 2)
#        patientid                   ALCOHOL
# 2  RAADC3-326688          Consumes alcohol
# 3  RAADC3-230262  Does not consume alcohol
# 4  RAADC3-098476          Consumes alcohol
# 5  RAADC3-086604          Consumes alcohol
# 6  RAADC3-164106          Consumes alcohol
# shape of intermediate table (178952, 15)
#        patientid       status BMI_max  HT_max WT_max PULSE_max TEMP_max  \
# 0  RAADC3-000002  PT_with_OBS     NaN     NaN    NaN       NaN      NaN
# 1  RAADC3-000005  PT_with_OBS    31.7     NaN   72.3        70      NaN
# 2  RAADC3-000006  PT_with_OBS    25.2  162.56  66.68        83      NaN
# 3  RAADC3-000008  PT_with_OBS     NaN  142.24    NaN       NaN      NaN
# 4  RAADC3-000009  PT_with_OBS    30.2  160.02  77.22        85     37.1
#
#   RESP_max HR_max PAIN_max PACKYRS_max DBP_max SBP_max         SMOKE  \
# 0      NaN    NaN        2         NaN     NaN     NaN           NaN
# 1      NaN    NaN      NaN         NaN      80     138  Never smoked
# 2      NaN    NaN        0         NaN      72     144  Never smoked
# 3      NaN    NaN        0           0     NaN     NaN  Never smoked
# 4     20.0    NaN      NaN         NaN      70     130           NaN
#
#                     ALCOHOL
# 0                       NaN
# 1  Does not consume alcohol
# 2  Does not consume alcohol
# 3  Does not consume alcohol
# 4                       NaN
# ========

# %%
df_obs_pivot_by_top15_obs = df.drop(['status'], axis=1)

# %%
df_obs_pivot_by_top15_obs.head()
# Out:
#        patientid BMI_max  HT_max  WT_max PULSE_max TEMP_max RESP_max HR_max  \
# 0  RAADC3-364095    21.8  172.72   64.98        73     36.9       20    NaN
# 1  RAADC3-026938     NaN     NaN     NaN       NaN      NaN      NaN    NaN
# 2  RAADC3-586023    33.5  162.56   88.45        86     36.9       16    NaN
# 3  RAADC3-593426    53.7   162.6  141.97       100     36.9       18    NaN
# 4  RAADC3-593426    53.7   162.6  141.97       100     36.9       18    NaN
#
#           SMOKE                      ALCOHOL PAIN_max PACKYRS_max DBP_max  \
# 0           NaN                          NaN      NaN         NaN      67
# 1  Never smoked                          NaN      NaN         NaN     NaN
# 2           NaN                          NaN      NaN         NaN      64
# 3  Never smoked  Unknown alcohol consumption      NaN         NaN      80
# 4  Never smoked             Consumes alcohol      NaN         NaN      80
#
#   SBP_max
# 0      95
# 1     NaN
# 2      92
# 3     142
# 4     142

# %%
df_obs_pivot_by_top15_obs.shape
# Out:
# (226785, 14)

# %%
df_obs_pid_for_left_merge.shape
# Out:
# (178952, 2)
