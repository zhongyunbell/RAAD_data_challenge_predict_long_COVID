# %% [markdown]
# ## Jan 25, 2023
# ## Summary of preload list generation for training / testing data preprocess

# %%
# !pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /opt/conda/lib/python3.9/site-packages (2023.1.0)
# Requirement already satisfied: pandas>=1.5.0 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (1.5.0)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (1.23.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.9/site-packages (from fastparquet) (2022.8.2)
# Requirement already satisfied: cramjam>=2.3 in /opt/conda/lib/python3.9/site-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from fastparquet) (21.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas>=1.5.0->fastparquet) (2022.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->fastparquet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.16.0)

# %%
import pandas as pd
import numpy as np
import os as os

pd.set_option('display.max_rows', 500)

import seaborn as sns
import matplotlib as plt

datadir = '/challenge/seeing-through-the-fog/data/train_data'

# %%
df_dia = pd.read_parquet(datadir + "/" + "diagnoses.parquet")
df_obs = pd.read_parquet(datadir + "/" + "observations.parquet")
df_med = pd.read_parquet(datadir + "/" + "medication.parquet")
df_lab = pd.read_parquet(datadir + "/" + "labs.parquet")
df_imm = pd.read_parquet(datadir + "/" + "immunization.parquet")
df_dem = pd.read_parquet(datadir + "/" + "demo.parquet")

# %%
def write_list_to_txt(output_file, lines):
    with open(output_file, 'w') as f:
        for line in lines:
            f.write(f"{line}\n")
            
            
def read_txt_to_list(input_file):
    with open(input_file) as file_in:
        list_of_lines = []
        for line in file_in:
            list_of_lines.append(line.rstrip())
    return list_of_lines

# %% [markdown]
# ### Generate Top15_obs_type.txt

# %%
df_obs_dedup = df_obs.drop_duplicates()
print(df_obs.shape)
print(df_obs_dedup.shape)
# Out:
# (14734829, 5)
# (5662458, 5)

# %%
df_obs_top_obstype_count =  df_obs_dedup.groupby('obs_type')[['patientid']].count().\
reset_index().sort_values(by='patientid', ascending=False)

df_obs_top_obstype_count.shape
# Out:
# (106, 2)

# %%
df_obs_top_obstype_count.head(20)
# Out:
#                             obs_type  patientid
# 89                               SBP     908449
# 40                               DBP     815406
# 85                             PULSE     750610
# 102                             TEMP     425857
# 87                              RESP     411511
# 38                               BMI     346390
# 105                               WT     345327
# 91                             SMOKE     324166
# 76                                HT     265536
# 75                                HR     243456
# 37                           ALCOHOL     219053
# 81                              PAIN     183940
# 34                   ACO.TOBACCO USE     124593
# 103                            UROUT     114996
# 80                        PACK_YEARS      54878
# 44                          EXERCISE      19234
# 31       ACO.PHQ-2.DEPRESSION SCREEN      14526
# 78                              LVEF      10788
# 36   ADVANCED CARE DIRECTIVE: YES/NO      10067
# 77       LAST MENSTRUAL PERIOD (LMP)       8989

# %%
top_15_obs_type_list = df_obs_top_obstype_count.head(15)['obs_type'].to_list()

# %%
write_list_to_txt("/home/huangz36/Top15_obs_type.txt", top_15_obs_type_list)

# %% [markdown]
# ### Generate Top40_labtests.txt and Top50_labtests.txt

# %%
df_lab_drop = df_lab.drop_duplicates()
df_lab_drop_short_group = df_lab_drop.groupby('test_name')[['patientid']].count().\
reset_index().sort_values(by='patientid', ascending=False)

# %%
df_lab_drop_short_group.head(50)
# Out:
#                                               test_name  patientid
# 1123            Oxygen saturation (SpO2).pulse oximetry     570326
# 657                                      Glucose.random     366950
# 1213                                      Potassium (K)     203356
# 449                                          Creatinine     201129
# 707                                    Hemoglobin (HGB)     196228
# 322                                       Calcium.total     193091
# 705                                    Hematocrit (HCT)     192723
# 1516                       White blood cell count (WBC)     189030
# 1282                         Red blood cell count (RBC)     181645
# 937    Mean corpuscular hemoglobin concentration (MCHC)     178592
# 938                       Mean corpuscular volume (MCV)     178267
# 936                   Mean corpuscular hemoglobin (MCH)     177472
# 1286            Red cell distribution width.CV (RDW-CV)     173370
# 1354                                        Sodium (Na)     167571
# 266                           Blood urea nitrogen (BUN)     164425
# 377                                       Chloride (Cl)     163990
# 1198                               Platelet count (PLT)     152497
# 344                          Carbon dioxide.total (CO2)     151916
# 1046                                Neutrophil.absolute     148025
# 915                                 Lymphocyte.absolute     146190
# 995                                   Monocyte.absolute     144010
# 147                                           Anion gap     136640
# 522                                 Eosinophil.absolute     136197
# 1201                         Platelet mean volume (MPV)     136047
# 1945                                          eGFR-Mayo     134527
# 1047                                 Neutrophil.percent     133723
# 918                                  Lymphocyte.percent     133718
# 212                                   Basophil.absolute     133284
# 996                                    Monocyte.percent     132216
# 1946                                      eGFR-Schwartz     130318
# 523                                  Eosinophil.percent     127317
# 213                                    Basophil.percent     127302
# 64                                              Albumin     122175
# 252                                     Bilirubin.total     115677
# 1249                                      Protein.total     115480
# 63                       Alanine aminotransferase (ALT)      97745
# 172                    Aspartate aminotransferase (AST)      96902
# 85                     Alkaline phosphatase.total (ALP)      94098
# 1316      SARS coronavirus 2 RNA (COVID-19).respiratory      83200
# 646   Glomerular filtration rate (eGFR).unspecified ...      75060
# 647   Glomerular filtration rate (eGFR).unspecified ...      68114
# 643   Glomerular filtration rate (eGFR).MDRD.Black.l...      56957
# 1358                    Specific gravity.urine.dipstick      53936
# 267     Blood urea nitrogen/creatinine ratio (BUN/CREA)      53564
# 933                                      Magnesium (Mg)      52912
# 1285           Red blood cells.nucleated (NRBC).percent      52837
# 432                                         Color.urine      48802
# 1252                             Protein.urine.dipstick      46772
# 1134                                  PH.urine.dipstick      46416
# 661                              Glucose.urine.dipstick      45219

# %%
Top_50_lab_test =  df_lab_drop_short_group.head(50)['test_name'].tolist()
Top_40_lab_test =  df_lab_drop_short_group.head(40)['test_name'].tolist()

# %%
write_list_to_txt("/home/huangz36/Top50_labtests.txt", Top_50_lab_test)
write_list_to_txt("/home/huangz36/Top40_labtests.txt", Top_40_lab_test)

# %% [markdown]
# ### Generate Top100_drug
# ### Further searched drug details and manually assigned annotated categories

# %%
df_med_dedup = df_med.drop_duplicates()
print(df_med.shape)
print(df_med_dedup.shape)
# Out:
# (6021819, 4)
# (4473741, 4)

# %%
df_med_dedup.head(5)
# Out:
#        patientid  days_to_covid_diag                          drug_name  \
# 0  RAADC3-504477                  21                          Mupirocin
# 1  RAADC3-241668                  15  Glucose Meter Test Control Strips
# 2  RAADC3-125094                  55                     Ergocalciferol
# 3  RAADC3-349386                  15    Vitamin B Complex and Vitamin C
# 4  RAADC3-556667                  21            Tiagabine Hydrochloride
#
#            ndc
# 0  68462018022
# 1  53885024450
# 2  69452015120
# 3  60258016001
# 4  00093503156

# %%
df_med_dedup_count = df_med_dedup.groupby('drug_name')[['patientid']].count().\
reset_index().sort_values(by='patientid', ascending=False)

# %%
df_med_dedup_count.head(100)
# Out:
#                                          drug_name  patientid
# 792                                  Acetaminophen     121654
# 1046                                       Aspirin      85551
# 1064                          Atorvastatin Calcium      80620
# 10060                              Sodium Chloride      72888
# 8918                           Pantoprazole Sodium      72031
# 851                              Albuterol Sulfate      71584
# 6715                                    Lisinopril      70013
# 933                            Amlodipine Besylate      55707
# 6678                          Levothyroxine Sodium      48536
# 4059                             Enoxaparin Sodium      47594
# 5006                                    Gabapentin      45701
# 8282                     Ondansetron Hydrochloride      44588
# 9067                            Potassium Chloride      43736
# 8272                                    Omeprazole      40296
# 4722                                    Furosemide      38203
# 2846                               Cholecalciferol      38105
# 7334                       Metformin Hydrochloride      37059
# 10032                     Sertraline Hydrochloride      35865
# 7447                     Multivitamin and Minerals      33773
# 5846                   Insulin Lispro, Recombinant      33538
# 4675                        Fluticasone Propionate      33270
# 5399                                Heparin Sodium      32827
# 6736                            Losartan Potassium      32391
# 806           Acetaminophen/Hydrocodone Bitartrate      32259
# 5063             Glucose Meter Test Control Strips      31507
# 10561                     Tamsulosin Hydrochloride      30973
# 7377                           Metoprolol Tartrate      30611
# 1085                                  Azithromycin      30322
# 7435                            Montelukast Sodium      29730
# 4585                                    Famotidine      29573
# 8315                       Oxycodone Hydrochloride      28502
# 9098                                    Prednisone      27804
# 7376                          Metoprolol Succinate      27712
# 7305                                     Melatonin      26734
# 3008                                Cyanocobalamin      25327
# 3037                 Cyclobenzaprine Hydrochloride      24852
# 5790                                     Ibuprofen      24688
# 1724                       Bupropion Hydrochloride      24168
# 4101                          Escitalopram Oxalate      24094
# 9047                      Polyethylene Glycol 3350      24024
# 889                                     Alprazolam      23314
# 6693                       Lidocaine Hydrochloride      22983
# 10683                      Trazodone Hydrochloride      21760
# 2762                                    Carvedilol      21504
# 5838                 Insulin Glargine, Recombinant      20719
# 992                                       Apixaban      19485
# 1590                                   Benzonatate      18882
# 5425                           Hydrochlorothiazide      18787
# 4621                               Ferrous Sulfate      18635
# 10660                       Tramadol Hydrochloride      18310
# 7450    Multivitamin, Minerals, and Nutriceuticals      18150
# 5834                   Insulin Aspart, Recombinant      18125
# 6733                                     Lorazepam      17756
# 3589                                      Dextrose      17642
# 3719                      Duloxetine Hydrochloride      16571
# 3671                               Docusate Sodium      16172
# 4692                                    Folic Acid      16170
# 3700                           Doxycycline Hyclate      16133
# 2940                  Clopidogrel Hydrogen Sulfate      16126
# 852          Albuterol Sulfate/Ipratropium Bromide      15959
# 3652                 Diphenhydramine Hydrochloride      15903
# 2651                      Ca Cl/K Cl/Na Cl/Na Lact      15897
# 9577                          Rosuvastatin Calcium      15760
# 7444                                  Multivitamin      15685
# 2901                       Citalopram Hydrobromide      15130
# 2810                      Cetirizine Hydrochloride      15106
# 9105                             Prenatal Vitamins      14535
# 10049                                  Simvastatin      14460
# 1021                                 Ascorbic Acid      14396
# 11256                     Vancomycin Hydrochloride      14165
# 7928                                 Nitroglycerin      13997
# 4089                                Ergocalciferol      13480
# 9203                           Quetiapine Fumarate      13280
# 7306                                     Meloxicam      13263
# 1728                       Buspirone Hydrochloride      12811
# 4648                                   Fluconazole      12771
# 5853                        Insulin Syringe/Needle      12663
# 6609                                        Lancet      12658
# 7436                              Morphine Sulfate      12610
# 6083                        Ketorolac Tromethamine      12468
# 5423                     Hydralazine Hydrochloride      12416
# 2790                            Ceftriaxone Sodium      12403
# 9099                                    Pregabalin      12403
# 6731                                    Loratadine      12288
# 807          Acetaminophen/Oxycodone Hydrochloride      12078
# 3621                             Diclofenac Sodium      12055
# 5903                        Isosorbide Mononitrate      11968
# 4663                      Fluoxetine Hydrochloride      11864
# 10689                      Triamcinolone Acetonide      11782
# 5061                                 Glucose Meter      11744
# 10096                               Spironolactone      11683
# 10656                                   Topiramate      11641
# 4676   Fluticasone Propionate/Salmeterol Xinafoate      11603
# 5450                   Hydromorphone Hydrochloride      11527
# 7369                            Methylprednisolone      11504
# 7284                               Magnesium Oxide      11448
# 7966                                 Nutriceutical      11029
# 2803                                    Cephalexin      10868
# 9127                                      Propofol      10849
# 876                                    Allopurinol      10800

# %%
top100_drug_list = df_med_dedup_count['drug_name'].to_list()
